# %% [markdown]
# <a href="https://colab.research.google.com/github/sugban/Python-Learning-/blob/main/Lesson27/Lesson_27_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Pandas reading, writing and maniputlating different files
#
# * Pandas is a powerful and flexible Python package that allows you to write and read Excel, CSV, JSON, html and many other types of files.
# * to write different types of files
# <pre>
# DataFrame.to_file-type('file_name/_path')
# </pre>
# * to read different file types
# <pre>
# pd.read_file-type('file_name/_path')
# </pre>
#
# |Methods|Description|
# |-------|-----------|
# |read_csv| to read csv file into dataframe |
# |to_csv| to write dataframe as csv file |
# |read_excel|to load data from Excel files|
# |to_excel| to save dataframe in an Excel file|
# |read_json | to load json file in dataframe|
# |to_json| to save dataframe as json file|
# |read_html|to load html file|
# |to_html| to save html file|

# %%
import pandas as pd

# %%
# to read csv file 

data = pd.read_csv('nba.csv')
data
# Out:
#               Name            Team  ...            College     Salary
# 0    Avery Bradley  Boston Celtics  ...              Texas  7730337.0
# 1      Jae Crowder  Boston Celtics  ...          Marquette  6796117.0
# 2     John Holland  Boston Celtics  ...  Boston University        NaN
# 3      R.J. Hunter  Boston Celtics  ...      Georgia State  1148640.0
# 4    Jonas Jerebko  Boston Celtics  ...                NaN  5000000.0
# ..             ...             ...  ...                ...        ...
# 453   Shelvin Mack       Utah Jazz  ...             Butler  2433333.0
# 454      Raul Neto       Utah Jazz  ...                NaN   900000.0
# 455   Tibor Pleiss       Utah Jazz  ...                NaN  2900000.0
# 456    Jeff Withey       Utah Jazz  ...             Kansas   947276.0
# 457            NaN             NaN  ...                NaN        NaN
#
# [458 rows x 9 columns]

# %% [markdown]
# #### max_rows
# * The number of rows returned is defined in Pandas option settings
# * We can check system's maximum rows with **pd.options.display.max_rows** statement

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %% [markdown]
# * the number is 60, which means that the DataFrame contains more than 60 rows
# * Thus, whenever we print dataframe, it will by default show only first and last 5 rows
# * We can increase the maximum number of rows to display the entire DataFrame by assigning a number to display option statement

# %%
pd.options.display.max_rows = 999

# %%
data = pd.read_csv('nba.csv')
data
# Out:
#                          Name  ...      Salary
# 0               Avery Bradley  ...   7730337.0
# 1                 Jae Crowder  ...   6796117.0
# 2                John Holland  ...         NaN
# 3                 R.J. Hunter  ...   1148640.0
# 4               Jonas Jerebko  ...   5000000.0
# 5                Amir Johnson  ...  12000000.0
# 6               Jordan Mickey  ...   1170960.0
# 7                Kelly Olynyk  ...   2165160.0
# 8                Terry Rozier  ...   1824360.0
# 9                Marcus Smart  ...   3431040.0
# 10            Jared Sullinger  ...   2569260.0
# 11              Isaiah Thomas  ...   6912869.0
# 12                Evan Turner  ...   3425510.0
# 13                James Young  ...   1749840.0
# 14               Tyler Zeller  ...   2616975.0
# 15           Bojan Bogdanovic  ...   3425510.0
# 16               Markel Brown  ...    845059.0
# 17            Wayne Ellington  ...   1500000.0
# 18    Rondae Hollis-Jefferson  ...   1335480.0
# ...

# %% [markdown]
# * to see first five or three rows, we use .head() method

# %%
data.head()  # by default head method prints first 5 rows
# Out:
#             Name            Team  Number  ... Weight            College     Salary
# 0  Avery Bradley  Boston Celtics     0.0  ...  180.0              Texas  7730337.0
# 1    Jae Crowder  Boston Celtics    99.0  ...  235.0          Marquette  6796117.0
# 2   John Holland  Boston Celtics    30.0  ...  205.0  Boston University        NaN
# 3    R.J. Hunter  Boston Celtics    28.0  ...  185.0      Georgia State  1148640.0
# 4  Jonas Jerebko  Boston Celtics     8.0  ...  231.0                NaN  5000000.0
#
# [5 rows x 9 columns]

# %%
# to get preferred number of rows
data.head(3)
# Out:
#             Name            Team  Number  ... Weight            College     Salary
# 0  Avery Bradley  Boston Celtics     0.0  ...  180.0              Texas  7730337.0
# 1    Jae Crowder  Boston Celtics    99.0  ...  235.0          Marquette  6796117.0
# 2   John Holland  Boston Celtics    30.0  ...  205.0  Boston University        NaN
#
# [3 rows x 9 columns]

# %%
# to get last rows, we use .tail() method
data.tail()  # by default it will show last 5 rows
# Out:
#              Name       Team  Number Position  ...  Height Weight  College     Salary
# 453  Shelvin Mack  Utah Jazz     8.0       PG  ...     6-3  203.0   Butler  2433333.0
# 454     Raul Neto  Utah Jazz    25.0       PG  ...     6-1  179.0      NaN   900000.0
# 455  Tibor Pleiss  Utah Jazz    21.0        C  ...     7-3  256.0      NaN  2900000.0
# 456   Jeff Withey  Utah Jazz    24.0        C  ...     7-0  231.0   Kansas   947276.0
# 457           NaN        NaN     NaN      NaN  ...     NaN    NaN      NaN        NaN
#
# [5 rows x 9 columns]

# %%
# to get selected number of rows
data.tail(2)
# Out:
#             Name       Team  Number Position  ...  Height Weight  College    Salary
# 456  Jeff Withey  Utah Jazz    24.0        C  ...     7-0  231.0   Kansas  947276.0
# 457          NaN        NaN     NaN      NaN  ...     NaN    NaN      NaN       NaN
#
# [2 rows x 9 columns]

# %%
# to check number of rows and column
data.shape
# Out:
# (458, 9)

# %%
# to check the type
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# to show all the column names
data.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
# to see index values
data.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %% [markdown]
# *to check information of the dataframe like, how many column and rows, column names and what datatype value and how many values each column has and all*

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
# to get all the statistical information 
data.describe() # it takes only numerical data
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %% [markdown]
# ####To select column

# %%
# for one column
data['Name']
# Out:
# 0                 Avery Bradley
# 1                   Jae Crowder
# 2                  John Holland
# 3                   R.J. Hunter
# 4                 Jonas Jerebko
# 5                  Amir Johnson
# 6                 Jordan Mickey
# 7                  Kelly Olynyk
# 8                  Terry Rozier
# 9                  Marcus Smart
# 10              Jared Sullinger
# 11                Isaiah Thomas
# 12                  Evan Turner
# 13                  James Young
# 14                 Tyler Zeller
# 15             Bojan Bogdanovic
# 16                 Markel Brown
# 17              Wayne Ellington
# 18      Rondae Hollis-Jefferson
# 19                 Jarrett Jack
# 20               Sergey Karasev
# 21              Sean Kilpatrick
# 22                 Shane Larkin
# 23                  Brook Lopez
# 24             Chris McCullough
# 25                  Willie Reed
# 26              Thomas Robinson
# 27                   Henry Sims
# 28                 Donald Sloan
# ...

# %%
data.Name
# Out:
# 0                 Avery Bradley
# 1                   Jae Crowder
# 2                  John Holland
# 3                   R.J. Hunter
# 4                 Jonas Jerebko
# 5                  Amir Johnson
# 6                 Jordan Mickey
# 7                  Kelly Olynyk
# 8                  Terry Rozier
# 9                  Marcus Smart
# 10              Jared Sullinger
# 11                Isaiah Thomas
# 12                  Evan Turner
# 13                  James Young
# 14                 Tyler Zeller
# 15             Bojan Bogdanovic
# 16                 Markel Brown
# 17              Wayne Ellington
# 18      Rondae Hollis-Jefferson
# 19                 Jarrett Jack
# 20               Sergey Karasev
# 21              Sean Kilpatrick
# 22                 Shane Larkin
# 23                  Brook Lopez
# 24             Chris McCullough
# 25                  Willie Reed
# 26              Thomas Robinson
# 27                   Henry Sims
# 28                 Donald Sloan
# ...

# %%
# for more than one column
data[['Name','Team','College']]
# Out:
#                          Name                    Team                College
# 0               Avery Bradley          Boston Celtics                  Texas
# 1                 Jae Crowder          Boston Celtics              Marquette
# 2                John Holland          Boston Celtics      Boston University
# 3                 R.J. Hunter          Boston Celtics          Georgia State
# 4               Jonas Jerebko          Boston Celtics                    NaN
# 5                Amir Johnson          Boston Celtics                    NaN
# 6               Jordan Mickey          Boston Celtics                    LSU
# 7                Kelly Olynyk          Boston Celtics                Gonzaga
# 8                Terry Rozier          Boston Celtics             Louisville
# 9                Marcus Smart          Boston Celtics         Oklahoma State
# 10            Jared Sullinger          Boston Celtics             Ohio State
# ...

# %% [markdown]
# If we use one square bracket, it will take column as series and with double square brackets, it will treat it as dataframe

# %%
type(data['College'])
# Out:
# pandas.core.series.Series

# %%
type(data[['College']])
# Out:
# pandas.core.frame.DataFrame

# %%
# to get the first or last 5 values of a column, again we use head and tail method
data['Name'].head()
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# Name: Name, dtype: object

# %%
data['Name'].tail()
# Out:
# 453    Shelvin Mack
# 454       Raul Neto
# 455    Tibor Pleiss
# 456     Jeff Withey
# 457             NaN
# Name: Name, dtype: object

# %% [markdown]
# #### To select rows

# %%
# we use slicing to get the data from rows
data[:2] # it will show first and second rows
# Out:
#             Name            Team  Number  ... Weight    College     Salary
# 0  Avery Bradley  Boston Celtics     0.0  ...  180.0      Texas  7730337.0
# 1    Jae Crowder  Boston Celtics    99.0  ...  235.0  Marquette  6796117.0
#
# [2 rows x 9 columns]

# %%
data[3:8] # it will show data from row 4 to 8
# Out:
#             Name            Team  Number  ... Weight        College      Salary
# 3    R.J. Hunter  Boston Celtics    28.0  ...  185.0  Georgia State   1148640.0
# 4  Jonas Jerebko  Boston Celtics     8.0  ...  231.0            NaN   5000000.0
# 5   Amir Johnson  Boston Celtics    90.0  ...  240.0            NaN  12000000.0
# 6  Jordan Mickey  Boston Celtics    55.0  ...  235.0            LSU   1170960.0
# 7   Kelly Olynyk  Boston Celtics    41.0  ...  238.0        Gonzaga   2165160.0
#
# [5 rows x 9 columns]

# %%
# to select from a particular column and row
data.Position[5:7]
# Out:
# 5    PF
# 6    PF
# Name: Position, dtype: object

# %%
data[['Number','Position','Age']][4:7]
# Out:
#    Number Position   Age
# 4     8.0       PF  29.0
# 5    90.0       PF  29.0
# 6    55.0       PF  21.0

# %% [markdown]
# #### Location based indexing (loc/iloc)
#
# * DataFrame.loc[] method is used to retrieve rows from Pandas DataFrame
# * Rows can also be selected by passing integer location to an iloc[] function

# %%
# will get third row details
data.loc[3]
# Out:
# Name           R.J. Hunter
# Team        Boston Celtics
# Number                28.0
# Position                SG
# Age                   22.0
# Height                 6-5
# Weight               185.0
# College      Georgia State
# Salary           1148640.0
# Name: 3, dtype: object

# %%
# to get data details from second to forth row
data.loc[1:4]
# Out:
#             Name            Team  Number  ... Weight            College     Salary
# 1    Jae Crowder  Boston Celtics    99.0  ...  235.0          Marquette  6796117.0
# 2   John Holland  Boston Celtics    30.0  ...  205.0  Boston University        NaN
# 3    R.J. Hunter  Boston Celtics    28.0  ...  185.0      Georgia State  1148640.0
# 4  Jonas Jerebko  Boston Celtics     8.0  ...  231.0                NaN  5000000.0
#
# [4 rows x 9 columns]

# %%
# To change the index
data.set_index('Name',inplace=True)
data
# Out:
#                                             Team  ...      Salary
# Name                                              ...
# Avery Bradley                     Boston Celtics  ...   7730337.0
# Jae Crowder                       Boston Celtics  ...   6796117.0
# John Holland                      Boston Celtics  ...         NaN
# R.J. Hunter                       Boston Celtics  ...   1148640.0
# Jonas Jerebko                     Boston Celtics  ...   5000000.0
# Amir Johnson                      Boston Celtics  ...  12000000.0
# Jordan Mickey                     Boston Celtics  ...   1170960.0
# Kelly Olynyk                      Boston Celtics  ...   2165160.0
# Terry Rozier                      Boston Celtics  ...   1824360.0
# Marcus Smart                      Boston Celtics  ...   3431040.0
# Jared Sullinger                   Boston Celtics  ...   2569260.0
# Isaiah Thomas                     Boston Celtics  ...   6912869.0
# ...

# %%
# to get data details from selected row 
data.loc['Markel Brown']
# Out:
# Team         Brooklyn Nets
# Number                22.0
# Position                SG
# Age                   24.0
# Height                 6-3
# Weight               190.0
# College     Oklahoma State
# Salary            845059.0
# Name: Markel Brown, dtype: object

# %%
# to get a particular row and column
data.loc['Markel Brown','Position']
# Out:
# 'SG'

# %%
# to get multiple rows
data.loc[['Markel Brown','Henry Sims']]
# Out:
#                        Team  Number Position  ...  Weight         College    Salary
# Name                                          ...
# Markel Brown  Brooklyn Nets    22.0       SG  ...   190.0  Oklahoma State  845059.0
# Henry Sims    Brooklyn Nets    14.0        C  ...   248.0      Georgetown  947276.0
#
# [2 rows x 8 columns]

# %%
# to get multiple rows and columns
data.loc[['Markel Brown','Henry Sims'],['Team','Position']]
# Out:
#                        Team Position
# Name
# Markel Brown  Brooklyn Nets       SG
# Henry Sims    Brooklyn Nets        C

# %% [markdown]
# **df.iloc** indexer is very similar to df.loc but only uses integer locations to make its selections

# %%
data.iloc[1]
# Out:
# Team        Boston Celtics
# Number                99.0
# Position                SF
# Age                   25.0
# Height                 6-6
# Weight               235.0
# College          Marquette
# Salary           6796117.0
# Name: Jae Crowder, dtype: object

# %%
data.iloc[4:8]
# Out:
#                          Team  Number Position  ...  Weight  College      Salary
# Name                                            ...
# Jonas Jerebko  Boston Celtics     8.0       PF  ...   231.0      NaN   5000000.0
# Amir Johnson   Boston Celtics    90.0       PF  ...   240.0      NaN  12000000.0
# Jordan Mickey  Boston Celtics    55.0       PF  ...   235.0      LSU   1170960.0
# Kelly Olynyk   Boston Celtics    41.0        C  ...   238.0  Gonzaga   2165160.0
#
# [4 rows x 8 columns]

# %%
# index can be reset by df.reset_index() method

data.reset_index(inplace=True)
data
# Out:
#                          Name  ...      Salary
# 0               Avery Bradley  ...   7730337.0
# 1                 Jae Crowder  ...   6796117.0
# 2                John Holland  ...         NaN
# 3                 R.J. Hunter  ...   1148640.0
# 4               Jonas Jerebko  ...   5000000.0
# 5                Amir Johnson  ...  12000000.0
# 6               Jordan Mickey  ...   1170960.0
# 7                Kelly Olynyk  ...   2165160.0
# 8                Terry Rozier  ...   1824360.0
# 9                Marcus Smart  ...   3431040.0
# 10            Jared Sullinger  ...   2569260.0
# 11              Isaiah Thomas  ...   6912869.0
# 12                Evan Turner  ...   3425510.0
# 13                James Young  ...   1749840.0
# 14               Tyler Zeller  ...   2616975.0
# 15           Bojan Bogdanovic  ...   3425510.0
# 16               Markel Brown  ...    845059.0
# 17            Wayne Ellington  ...   1500000.0
# 18    Rondae Hollis-Jefferson  ...   1335480.0
# ...

# %%
# to get selected rows

data.iloc[[10,15,20,25]]
# Out:
#                 Name            Team  Number  ... Weight      College     Salary
# 10   Jared Sullinger  Boston Celtics     7.0  ...  260.0   Ohio State  2569260.0
# 15  Bojan Bogdanovic   Brooklyn Nets    44.0  ...  216.0          NaN  3425510.0
# 20    Sergey Karasev   Brooklyn Nets    10.0  ...  208.0          NaN  1599840.0
# 25       Willie Reed   Brooklyn Nets    33.0  ...  220.0  Saint Louis   947276.0
#
# [4 rows x 9 columns]

# %%
# to get selected row and column

data.iloc[[10,15,20,25],5:10]
# Out:
#    Height  Weight      College     Salary
# 10    6-9   260.0   Ohio State  2569260.0
# 15    6-8   216.0          NaN  3425510.0
# 20    6-7   208.0          NaN  1599840.0
# 25   6-10   220.0  Saint Louis   947276.0

# %%
data.iloc[[10,15,20,25],[0,1,3,4,7,8]]
# Out:
#                 Name            Team Position   Age      College     Salary
# 10   Jared Sullinger  Boston Celtics        C  24.0   Ohio State  2569260.0
# 15  Bojan Bogdanovic   Brooklyn Nets       SG  27.0          NaN  3425510.0
# 20    Sergey Karasev   Brooklyn Nets       SG  22.0          NaN  1599840.0
# 25       Willie Reed   Brooklyn Nets       PF  26.0  Saint Louis   947276.0

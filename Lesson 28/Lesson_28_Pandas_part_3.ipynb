# %% [markdown]
# <a href="https://colab.research.google.com/github/sugban/Python-Learning-/blob/main/Lesson%2028/Lesson_28_Pandas_part_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Pandas reading, writing and maniputlating different files
#
# * Pandas is a powerful and flexible Python package that allows you to write and read Excel, CSV, JSON, html and many other types of files.
# * to write different types of files
# <pre>
# DataFrame.to_file-type('file_name/_path')
# </pre>

# %%
import pandas as pd

# %%
df = pd.read_excel('data.xlsx')
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130    4091.0
# 1          60    117       145    4790.0
# 2          60    103       135    3400.0
# 3          45    109       175    2824.0
# 4          45    117       148    4060.0
# ..        ...    ...       ...       ...
# 164        60    105       140    2908.0
# 165        60    110       145    3000.0
# 166        60    115       145    3102.0
# 167        75    120       150    3204.0
# 168        75    125       150    3304.0
#
# [169 rows x 4 columns]

# %%
df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130    4091.0
# 1        60    117       145    4790.0
# 2        60    103       135    3400.0
# 3        45    109       175    2824.0
# 4        45    117       148    4060.0

# %%
df.tail()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140    2908.0
# 165        60    110       145    3000.0
# 166        60    115       145    3102.0
# 167        75    120       150    3204.0
# 168        75    125       150    3304.0

# %%
df.columns
# Out:
# Index(['Duration', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
# Working with series

ser=df['Pulse']
ser.head()
# Out:
# 0    110
# 1    117
# 2    103
# 3    109
# 4    117
# Name: Pulse, dtype: int64

# %%
ser.dtype
# Out:
# dtype('int64')

# %%
ser.shape
# Out:
# (169,)

# %%
ser.size
# Out:
# 169

# %%
ser.describe()
# Out:
# count    169.000000
# mean     107.461538
# std       14.510259
# min       80.000000
# 25%      100.000000
# 50%      105.000000
# 75%      111.000000
# max      159.000000
# Name: Pulse, dtype: float64

# %%
ser.index
# Out:
# RangeIndex(start=0, stop=169, step=1)

# %%
ser.sum()
# Out:
# 18161

# %%
ser.mean()
# Out:
# 107.46153846153847

# %%
ser.median()
# Out:
# 105.0

# %%
ser.std()
# Out:
# 14.510259096501994

# %%
ser.min()
# Out:
# 80

# %%
ser.max()
# Out:
# 159

# %%
ser.unique()
# Out:
# array([110, 117, 103, 109, 102, 104,  98, 100, 106,  90,  97, 108, 130,
#        105,  92, 101,  93, 107, 114, 111,  99, 123, 118, 136, 121, 115,
#        153, 159, 149, 151, 129,  83,  80, 150,  95, 152, 137, 124, 116,
#        112, 119, 113, 141, 122,  85, 120, 125])

# %%
ser.nunique()
# Out:
# 47

# %%
ser.value_counts()
# Out:
# 100    19
# 90     12
# 103     9
# 109     9
# 107     8
# 108     7
# 97      7
# 110     7
# 106     6
# 111     6
# 98      6
# 105     6
# 102     6
# 104     4
# 114     4
# 95      3
# 115     3
# 117     3
# 118     3
# 136     3
# 93      3
# 92      3
# 99      2
# 151     2
# 112     2
# 123     2
# 80      2
# 150     2
# 101     2
# 149     1
# 116     1
# 120     1
# 85      1
# 122     1
# 141     1
# 113     1
# 119     1
# 124     1
# 159     1
# 137     1
# 152     1
# 130     1
# 121     1
# 153     1
# 83      1
# 129     1
# 125     1
# Name: Pulse, dtype: int64

# %%
ser.value_counts(ascending=False)
# Out:
# 100    19
# 90     12
# 103     9
# 109     9
# 107     8
# 108     7
# 97      7
# 110     7
# 106     6
# 111     6
# 98      6
# 105     6
# 102     6
# 104     4
# 114     4
# 95      3
# 115     3
# 117     3
# 118     3
# 136     3
# 93      3
# 92      3
# 99      2
# 151     2
# 112     2
# 123     2
# 80      2
# 150     2
# 101     2
# 149     1
# 116     1
# 120     1
# 85      1
# 122     1
# 141     1
# 113     1
# 119     1
# 124     1
# 159     1
# 137     1
# 152     1
# 130     1
# 121     1
# 153     1
# 83      1
# 129     1
# 125     1
# Name: Pulse, dtype: int64

# %%
ser.value_counts(bins=3)
# Out:
# (79.92, 106.333]      92
# (106.333, 132.667]    64
# (132.667, 159.0]      13
# Name: Pulse, dtype: int64

# %%
ser.sort_index(ascending=False)
# Out:
# 168    125
# 167    120
# 166    115
# 165    110
# 164    105
#       ...
# 4      117
# 3      109
# 2      103
# 1      117
# 0      110
# Name: Pulse, Length: 169, dtype: int64

# %%
ser.sort_values(ascending=True)
# Out:
# 159     80
# 93      80
# 89      83
# 160     85
# 92      90
#       ...
# 85     151
# 95     151
# 97     152
# 58     153
# 80     159
# Name: Pulse, Length: 169, dtype: int64

# %%
# converting series into a list
ser.tolist()
# Out:
# [110,
#  117,
#  103,
#  109,
#  117,
#  102,
#  110,
#  104,
#  109,
#  98,
#  103,
#  100,
#  106,
#  104,
#  98,
#  98,
#  100,
#  90,
#  103,
#  97,
#  108,
#  100,
#  130,
#  105,
#  102,
#  100,
#  92,
#  103,
#  100,
#  102,
#  92,
#  90,
#  101,
#  93,
#  107,
#  114,
#  102,
#  100,
#  100,
#  104,
#  90,
#  98,
#  100,
#  111,
#  111,
#  99,
#  109,
#  111,
#  108,
#  111,
#  107,
#  123,
#  106,
#  118,
#  136,
#  121,
#  118,
#  115,
#  153,
#  123,
#  108,
#  110,
#  109,
#  118,
#  110,
#  90,
#  105,
#  107,
#  106,
#  108,
#  97,
#  109,
#  100,
#  97,
#  114,
#  98,
#  105,
#  110,
#  100,
#  100,
#  159,
#  149,
#  103,
#  100,
#  100,
#  151,
#  102,
#  100,
#  129,
#  83,
#  101,
#  107,
#  90,
#  80,
#  150,
#  151,
#  95,
#  152,
#  109,
#  93,
#  95,
#  90,
#  90,
#  90,
#  92,
#  93,
#  90,
#  90,
#  90,
#  137,
#  102,
#  107,
#  124,
#  100,
#  108,
#  108,
#  116,
#  97,
#  105,
#  103,
#  112,
#  100,
#  119,
#  107,
#  111,
#  98,
#  97,
#  109,
#  99,
# ...

# %%
# to array
ser.values
# Out:
# array([110, 117, 103, 109, 117, 102, 110, 104, 109,  98, 103, 100, 106,
#        104,  98,  98, 100,  90, 103,  97, 108, 100, 130, 105, 102, 100,
#         92, 103, 100, 102,  92,  90, 101,  93, 107, 114, 102, 100, 100,
#        104,  90,  98, 100, 111, 111,  99, 109, 111, 108, 111, 107, 123,
#        106, 118, 136, 121, 118, 115, 153, 123, 108, 110, 109, 118, 110,
#         90, 105, 107, 106, 108,  97, 109, 100,  97, 114,  98, 105, 110,
#        100, 100, 159, 149, 103, 100, 100, 151, 102, 100, 129,  83, 101,
#        107,  90,  80, 150, 151,  95, 152, 109,  93,  95,  90,  90,  90,
#         92,  93,  90,  90,  90, 137, 102, 107, 124, 100, 108, 108, 116,
#         97, 105, 103, 112, 100, 119, 107, 111,  98,  97, 109,  99, 114,
#        104, 107, 103, 106, 103, 136, 117, 115, 113, 141, 108,  97, 100,
#        122, 136, 106, 107, 112, 103, 110, 106, 109, 109, 150, 105, 111,
#         97, 100, 114,  80,  85,  90,  95, 100, 105, 110, 115, 120, 125])

# %%
ser.nsmallest() # first 5 smallest
# Out:
# 93     80
# 159    80
# 89     83
# 160    85
# 17     90
# Name: Pulse, dtype: int64

# %%
# to get the index number of the one smallest value 

ser.nsmallest().index[0]
# Out:
# 93

# %%
# to get first 5 largest
ser.nlargest()
# Out:
# 80    159
# 58    153
# 97    152
# 85    151
# 95    151
# Name: Pulse, dtype: int64

# %%
ser.nlargest().index[0]
# Out:
# 80

# %%
#to get the index of the largest and smallest value
ser.idxmax()
# Out:
# 80

# %%
ser.idxmin()
# Out:
# 93

# %%
ser.to_frame() # to see series into dataframe
# Out:
#      Pulse
# 0      110
# 1      117
# 2      103
# 3      109
# 4      117
# ..     ...
# 164    105
# 165    110
# 166    115
# 167    120
# 168    125
#
# [169 rows x 1 columns]

# %%
# to write dataframe as html file
from IPython.display import HTML

df.to_html('data.html')

# %%
df1=pd.read_html('data.html')[0]
df1
# Out:
#      Unnamed: 0  Duration  Pulse  Maxpulse  Calories
# 0             0        60    110       130    4091.0
# 1             1        60    117       145    4790.0
# 2             2        60    103       135    3400.0
# 3             3        45    109       175    2824.0
# 4             4        45    117       148    4060.0
# ..          ...       ...    ...       ...       ...
# 164         164        60    105       140    2908.0
# 165         165        60    110       145    3000.0
# 166         166        60    115       145    3102.0
# 167         167        75    120       150    3204.0
# 168         168        75    125       150    3304.0
#
# [169 rows x 5 columns]

# %%
html = df.to_html()
print(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Duration</th>
#       <th>Pulse</th>
#       <th>Maxpulse</th>
#       <th>Calories</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>60</td>
#       <td>110</td>
#       <td>130</td>
#       <td>4091.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>60</td>
#       <td>117</td>
#       <td>145</td>
#       <td>4790.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>60</td>
#       <td>103</td>
#       <td>135</td>
#       <td>3400.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>45</td>
#       <td>109</td>
#       <td>175</td>
#       <td>2824.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>45</td>
#       <td>117</td>
#       <td>148</td>
#       <td>4060.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>60</td>
#       <td>102</td>
#       <td>127</td>
# ...
